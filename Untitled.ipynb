# %% [markdown]
# # YOLO
# <h2><i>Install Packages</i></h2>
# <h4>conda install pytorch torchvision torchaudio cpuonly -c pytorch -y</h4>
# <h4>conda install -c conda-forge ultralytics -y</h4>

# %%
import torch
import numpy as np
import cv2
from ultralytics import YOLO
from matplotlib import pyplot as plt

# %%
# Run detection on an online image
# results = model.predict(source="https://ultralytics.com/images/zidane.jpg", show=True)

# %%
# load model
model = YOLO("yolov8n.pt")

# %%
model

# %%
img = "https://ultralytics.com/images/zidane.jpg"

# %%
results = model(img)[0]
results.verbose()
# Out:
# Found https://ultralytics.com/images/zidane.jpg locally at zidane.jpg
# image 1/1 /Users/briankimanzi/Documents/programmingLanguages/PythonProgramming/ObjectDetection/zidane.jpg: 384x640 2 persons, 1 tie, 3862.8ms
# Speed: 25.6ms preprocess, 3862.8ms inference, 13.5ms postprocess per image at shape (1, 3, 384, 640)
# '2 persons, 1 tie, '

# %%
annotated_img = results.plot()
plt.imshow(annotated_img)
plt.axis("off")
plt.show()

# %%
np.array(results.plot()).shape
# Out:
# (720, 1280, 3)
